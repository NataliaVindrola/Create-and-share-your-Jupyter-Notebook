# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## **Natalia Vindrola**
# Data Scientist

# %% [markdown]
# ### *I am interested in Data Scientist because data is the most valuable asset that every company has, and I would like to help them to use it right.*

# %%
## Write and execute code

# %%
(5*4)+80
# Out:
# 100

# %% [markdown]
# ***
# * Main bullet point
#     * sub bullet point
#     * sub bullet point
# 1. Numbered list
# 1. Numbered list
# 1. Numbered list
# 1. Numbered list
#     1. Substep
#     1. Substep
#
#  | Head | Head |
#  | ---- | ---- |
#  | cell | Cell |
#
#  __[link text](https://www.google.com.pe/?pli=1&authuser=1)
#
# ![citizen-data-scientist-predict-diagram-outlines.svg](attachment:fb4317cf-8ff1-46c3-be84-fc85df1f73c0.svg)
#
# `Highlight`
#
# <code> Highlight
#
# > Blocked quotes
#
# > Blocked quotes 1
# >
# > Blocked quotes
#
# ~~Strikethrough~~
